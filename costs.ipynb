# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

samples = 1000
target = np.zeros(samples).reshape(samples, 1)
offset = np.linspace(0, 1, samples).reshape(samples, 1)
prediction = target + offset
assert target.shape == prediction.shape

def show(cost):
    plt.plot(offset, np.sum(cost, axis=1))
    plt.xlabel('offset')
    plt.ylabel('cost')

# %%
# Squared
cost = (prediction - target) ** 2 / 2
show(cost)

# %%
# Cross Entropy
epsilon = 1e-15
pred = np.clip(prediction, epsilon, 1 - epsilon)
cost = target * np.log(pred) + (1 - target) * np.log(1 - pred)
cost = -cost / len(target)
show(cost)
